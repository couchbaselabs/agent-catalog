# %% [markdown]
# # My-Agent Quality Analysis

# %%
import warnings

warnings.simplefilter(action="ignore", category=FutureWarning)

# %%
import couchbase.auth
import couchbase.cluster
import couchbase.options
import datasets
import dotenv
import os

dotenv.load_dotenv()

conn_opts = couchbase.options.ClusterOptions(
    authenticator=couchbase.auth.PasswordAuthenticator(
        os.getenv("AGENT_CATALOG_USERNAME"), os.getenv("AGENT_CATALOG_PASSWORD")
    )
)
cluster = couchbase.cluster.Cluster.connect(os.getenv("AGENT_CATALOG_CONN_STRING"), conn_opts)

# We will treat the results of our tools as RAGAS context (we need to transpose our generations).
query = cluster.analytics_query("""
    WITH LatestGenerations AS (
        FROM
            `travel-sample`.agent_activity.raw_logs AS s
        WHERE 
            s.`grouping` IS NOT NULL
        GROUP BY 
            s.`grouping`,
            s.session
            GROUP AS g
        LETTING
            msgs = (
                FROM 
                    g AS gi
                SELECT
                    gi.s.content.content,
                    gi.s.content.tool_calls,
                    gi.s.kind,
                    gi.s.timestamp,
                    ROW_NUMBER() OVER () AS row_num
            ),
            first_human = (
                FROM 
                    msgs AS msgsi
                WHERE 
                    msgsi.kind = "human"
                SELECT
                    msgsi.content,
                    msgsi.row_num
                ORDER BY
                    STR_TO_MILLIS(msgsi.timestamp) ASC
                LIMIT 1
            )[0],
            last_message = (
                FROM
                    msgs AS msgsi
                SELECT 
                    COALESCE(msgsi.content, msgsi.tool_calls) AS content,
                    msgsi.row_num
                ORDER BY 
                    STR_TO_MILLIS(msgsi.timestamp) DESC
                LIMIT 1
            )[0],
            context = (
                FROM 
                    msgs AS msgsi
                WHERE
                    msgsi.row_num != first_human.row_num AND 
                    msgsi.row_num != last_message.row_num
                SELECT VALUE
                   COALESCE(msgsi.content, msgsi.tool_calls)
            )
        SELECT
            first_human.content AS question,
            last_message.content AS answer,
            context AS contexts,
            ROW_NUMBER() OVER () AS row_num
    )
    SELECT
        (FROM LatestGenerations e SELECT VALUE e.question ORDER BY e.row_num) AS question,
        (FROM LatestGenerations e SELECT VALUE e.answer ORDER BY e.row_num) AS answer,
        (FROM LatestGenerations e SELECT VALUE e.contexts ORDER BY e.row_num) AS contexts
""")
ragas_dataset = datasets.Dataset.from_dict(list(query)[0])
ragas_dataset
# Out:
# Dataset({
#     features: ['answer', 'contexts', 'question'],
#     num_rows: 37
# })

# %%
import langchain_openai
import ragas.llms
import ragas.metrics

chat_model = langchain_openai.ChatOpenAI(model="gpt-4o")
evaluator_llm = ragas.llms.LangchainLLMWrapper(chat_model)
score = ragas.evaluate(
    ragas_dataset,
    metrics=[
        ragas.metrics.AnswerRelevancy(llm=evaluator_llm),
        ragas.metrics.ContextUtilization(llm=evaluator_llm),
    ],
)
score.to_pandas()
# Out:
# Evaluating: 100%|██████████| 74/74 [00:32<00:00,  2.30it/s]
#                                            user_input  \
# 0   (The following message is from the orchestrato...
# 1   (The following message is from the orchestrato...
# 2   (The following message is from the orchestrato...
# 3   (The following message is from the orchestrato...
# 4   (The following message is from the orchestrato...
# 5   (The following message is from the orchestrato...
# 6   (The following message is from the orchestrato...
# 7   (The following message is from the orchestrato...
# 8   (The following message is from the orchestrato...
# 9   (The following message is from the orchestrato...
# 10  (The following message is from the orchestrato...
# 11  (The following message is from the orchestrato...
# 12  (The following message is from the orchestrato...
# 13  (The following message is from the orchestrato...
# 14  (The following message is from the orchestrato...
# 15  (The following message is from the orchestrato...
# 16  (The following message is from the orchestrato...
# 17  (The following message is from the orchestrato...
# 18  (The following message is from the orchestrato...
# 19  (The following message is from the orchestrato...
# 20  (The following message is from the orchestrato...
# 21  (The following message is from the orchestrato...
# 22  (The following message is from the orchestrato...
# 23  (The following message is from the orchestrato...
# 24  (The following message is from the orchestrato...
# 25  (The following message is from the orchestrato...
# 26  (The following message is from the orchestrato...
# 27  (The following message is from the orchestrato...
# 28  (The following message is from the orchestrato...
# 29  (The following message is from the orchestrato...
# 30  (The following message is from the orchestrato...
# 31  (The following message is from the orchestrato...
# 32  (The following message is from the orchestrato...
# 33  (The following message is from the orchestrato...
# 34  (The following message is from the orchestrato...
# 35  (The following message is from the orchestrato...
# 36  (The following message is from the orchestrato...
#
#                                    retrieved_contexts  \
# 0   [# Agent\n\nI am a workflow orchestrator. You ...
# 1   [# Agent\n\nI am a workflow orchestrator. You ...
# 2   [# Agent\n\nI am a workflow orchestrator. You ...
# 3   [# Agent\n\nI am a workflow orchestrator. You ...
# 4   [# Agent\n\nI am a workflow orchestrator. You ...
# 5   [# Agent\n\nI am a workflow orchestrator. You ...
# 6   [# Agent\n\nI am a workflow orchestrator. You ...
# 7   [# Agent\n\nI am a workflow orchestrator. You ...
# 8   [# Agent\n\nI am a workflow orchestrator. You ...
# 9   [# Agent\n\nI am a workflow orchestrator. You ...
# 10  [# Agent\n\nI am a workflow orchestrator. You ...
# 11  [# Agent\n\nI am a workflow orchestrator. You ...
# 12  [# Agent\n\nI am a workflow orchestrator. You ...
# 13  [# Agent\n\nI am a workflow orchestrator. You ...
# 14  [# Agent\n\nI am a workflow orchestrator. You ...
# 15  [# Agent\n\nI am a workflow orchestrator. You ...
# 16  [# Agent\n\nI am a workflow orchestrator. You ...
# 17  [# Agent\n\nI am a workflow orchestrator. You ...
# 18  [# Agent\n\nI am a workflow orchestrator. You ...
# 19  [# Agent\n\nI am a workflow orchestrator. You ...
# 20  [# Agent\n\nI am a workflow orchestrator. You ...
# 21  [# Agent\n\nI am a workflow orchestrator. You ...
# 22  [# Agent\n\nI am a workflow orchestrator. You ...
# 23  [# Agent\n\nI am a workflow orchestrator. You ...
# 24  [# Agent\n\nI am a workflow orchestrator. You ...
# 25  [# Agent\n\nI am a workflow orchestrator. You ...
# 26  [# Agent\n\nI am a workflow orchestrator. You ...
# 27  [# Agent\n\nI am a workflow orchestrator. You ...
# 28  [# Agent\n\nI am a workflow orchestrator. You ...
# 29  [# Agent\n\nI am a workflow orchestrator. You ...
# 30  [# Agent\n\nI am a workflow orchestrator. You ...
# 31  [# Agent\n\nI am a workflow orchestrator. You ...
# 32  [# Agent\n\nI am a workflow orchestrator. You ...
# 33  [# Agent\n\nI am a workflow orchestrator. You ...
# 34  [# Agent\n\nI am a workflow orchestrator. You ...
# 35  [# Agent\n\nI am a workflow orchestrator. You ...
# 36  [# Agent\n\nI am a workflow orchestrator. You ...
#
#                                              response  answer_relevancy  \
# 0   talk_to_user({'message': 'Please provide the n...          0.847936
# 1   talk_to_user({'message': 'Please provide the s...          0.844437
# 2   talk_to_user({'message': 'Please provide the s...          0.837004
# 3   talk_to_user({'message': 'Please provide the s...          0.869787
# 4   find_direct_routes_between_airports({'argument...          0.815323
# 5   find_direct_routes_between_airports({'argument...          0.793692
# 6   mark_task_69c6c897_successful({'source_airport...          0.792364
# 7   find_routes_with_one_layover({'argument_input'...          0.814374
# 8   mark_task_bd89f75d_successful({'source_airport...          0.786626
# 9   mark_task_d5ebe28e_successful({'task_result': 1})          0.790309
# 10  mark_task_4ff4cccf_successful({'task_result': 1})          0.798112
# 11  find_direct_routes_between_airports({'argument...          0.820065
# 12  talk_to_user({'message': "Do you want to conti...          0.812199
# 13  talk_to_user({'message': "I couldn't find any ...          0.000000
# 14  mark_task_40152efc_successful({'source_airport...          0.806050
# 15  mark_task_2e9dcb5f_failed({'reason': 'The user...          0.778110
# 16  find_direct_routes_between_airports({'argument...          0.795982
# 17  talk_to_user({'message': "It seems like you're...          0.853829
# 18  mark_task_ae645dcc_successful({'task_result': ...          0.805413
# 19  mark_task_193fbd9d_successful({'task_result': ...          0.790767
# 20  find_direct_routes_between_airports({'argument...          0.821307
# 21  mark_task_947d7c14_successful({'task_result': 1})          0.792459
# 22  talk_to_user({'message': 'Please provide the s...          0.865493
# 23  talk_to_user({'message': 'Please provide the s...          0.834859
# 24  mark_task_7391cf1b_successful({'task_result': 1})          0.797994
# 25  mark_task_df98ad24_successful({'source_airport...          0.828885
# 26  mark_task_b4a2b7a6_successful({'task_result': ...          0.776079
# 27  talk_to_user({'message': "Do you want to conti...          0.824495
# 28  talk_to_user({'message': 'Please provide the s...          0.835890
# 29  mark_task_c47c9247_successful({'task_result': ...          0.789993
# 30  talk_to_user({'message': "I couldn't find any ...          0.000000
# 31  mark_task_3b2ea070_successful({'source_airport...          0.809387
# 32  talk_to_user({'message': "Do you want to conti...          0.802800
# 33  find_direct_routes_between_airports({'argument...          0.824291
# 34  find_routes_with_one_layover({'argument_input'...          0.814705
# 35  talk_to_user({'message': "Do you want to conti...          0.803073
# 36  talk_to_user({'message': 'Please provide the s...          0.862259
#
#     context_utilization
# 0              1.000000
# 1              1.000000
# 2              1.000000
# 3              1.000000
# 4              1.000000
# 5              1.000000
# 6              0.833333
# 7              1.000000
# 8              0.833333
# 9              1.000000
# 10             0.000000
# 11             0.587302
# 12             1.000000
# 13             0.916667
# 14             1.000000
# 15             0.000000
# 16             1.000000
# 17             0.000000
# 18             0.242063
# 19             1.000000
# 20             1.000000
# 21             1.000000
# 22             1.000000
# 23             1.000000
# 24             1.000000
# 25             0.833333
# 26             1.000000
# 27             1.000000
# 28             1.000000
# 29             1.000000
# 30             0.250000
# 31             0.833333
# 32             1.000000
# 33             1.000000
# 34             1.000000
# 35             1.000000
# 36             1.000000

# %% [markdown]
# # Agent Quality around Walks

# %%
# We want to make sure that our agent is routed to the right tasks.
# We can do this by analyzing the agent's walks.
query = cluster.analytics_query("""
    FROM
        `travel-sample`.agent_activity.Walks() t
    SELECT
        t;
""")
list(query)
# Out:
# [{'msgs': [{'content': {'extra': {'status': 'FAILED'},
#      'from_node': 'find_source_and_dest'},
#     'kind': 'transition',
#     'msg_num': 13,
#     'timestamp': '2024-11-20T13:16:41.778069-08:00'}],
#   'sid': 'e73eb8777f194cecaef9954864f1d7b4',
#   'vid': {'identifier': '582e23b276386435c59289c13d22df58873631bf',
#    'timestamp': '2024-11-20T18:51:38.490768Z'}},
#  {'msgs': [{'content': {'extra': {'status': 'RUNNING'},
#      'to_node': 'find_source_and_dest'},
#     'kind': 'transition',
#     'msg_num': 1,
#     'timestamp': '2024-11-20T13:03:27.041697-08:00'},
#    {'content': {'extra': {'status': 'SUCCESSFUL'},
#      'from_node': 'find_source_and_dest'},
#     'kind': 'transition',
#     'msg_num': 10,
#     'timestamp': '2024-11-20T13:04:00.754507-08:00'},
#    {'content': {'extra': {'status': 'RUNNING'},
#      'to_node': 'find_travel_routes'},
#     'kind': 'transition',
#     'msg_num': 11,
#     'timestamp': '2024-11-20T13:04:01.318589-08:00'},
#    {'content': {'extra': {'status': 'SUCCESSFUL'},
#      'from_node': 'find_travel_routes'},
#     'kind': 'transition',
#     'msg_num': 18,
#     'timestamp': '2024-11-20T13:04:03.842446-08:00'},
#    {'content': {'extra': {'status': 'RUNNING'}, 'to_node': 'ask_to_continue'},
#     'kind': 'transition',
#     'msg_num': 19,
#     'timestamp': '2024-11-20T13:04:04.275719-08:00'},
#    {'content': {'extra': {'status': 'SUCCESSFUL'},
#      'from_node': 'ask_to_continue'},
#     'kind': 'transition',
#     'msg_num': 28,
#     'timestamp': '2024-11-20T13:04:08.953220-08:00'}],
#   'sid': '4431869c6e4541e1a25b1c6f9bec9221',
#   'vid': {'identifier': '582e23b276386435c59289c13d22df58873631bf',
#    'timestamp': '2024-11-20T18:51:38.490768Z'}}]

# %% [markdown]
# # Agent Quality around Tool Selection

# %%
# We want to assert that our agent is selecting the right tools for the right tasks.
# Again, we provide a view to help you enable this.
query = cluster.analytics_query("""
    FROM
        `travel-sample`.agent_activity.ToolCalls() t
    SELECT
        t;
""")
list(query)
# Out:
# [{'t': {'sid': 'e73eb8777f194cecaef9954864f1d7b4',
#    'tool_calls': [{'tool_args': {'message': 'Please provide the source airport and the destination airport so I can return their IATA codes for you.'},
#      'tool_call_id': 'call_nCkJ33tZQH8OgxEbQ3JNLa3Y',
#      'tool_name': 'talk_to_user',
#      'tool_result': "i want to go to Mars, I'm from Saturn",
#      'tool_status': 'success'},
#     {'tool_args': {'message': 'Please provide the source airport and the destination airport so I can return their IATA codes for you.'},
#      'tool_call_id': 'call_nCkJ33tZQH8OgxEbQ3JNLa3Y',
#      'tool_name': 'talk_to_user',
#      'tool_result': "i want to go to Mars, I'm from Saturn",
#      'tool_status': 'success'},
#     {'tool_args': {'message': "It seems like you're mentioning planets! For this task, I need the names of actual airports on Earth. Could you please provide the name of the source airport and the destination airport?"},
#      'tool_call_id': 'call_JJHaneHQs3JFqVobBZZ1x3TI',
#      'tool_name': 'talk_to_user',
#      'tool_result': 'no',
#      'tool_status': 'success'},
#     {'tool_args': {'message': "It seems like you're mentioning planets! For this task, I need the names of actual airports on Earth. Could you please provide the name of the source airport and the destination airport?"},
#      'tool_call_id': 'call_JJHaneHQs3JFqVobBZZ1x3TI',
#      'tool_name': 'talk_to_user',
#      'tool_result': 'no',
#      'tool_status': 'success'}],
#    'vid': {'identifier': '582e23b276386435c59289c13d22df58873631bf',
#     'timestamp': '2024-11-20T18:51:38.490768Z'}}},
#  {'t': {'sid': 'be4c0d89e72b447f92b8d11879470ce1',
#    'tool_calls': [{'tool_args': {'message': 'Please provide the source airport and the destination airport so I can return their IATA codes for you.'},
#      'tool_call_id': 'call_OhmSb2zOZGgxbD5DGNQIhYNT',
#      'tool_name': 'talk_to_user',
#      'tool_result': 'I need to go to Orange County. I am in Cupertino.',
#      'tool_status': 'success'},
#     {'tool_args': {'message': 'Please provide the source airport and the destination airport so I can return their IATA codes for you.'},
#      'tool_call_id': 'call_OhmSb2zOZGgxbD5DGNQIhYNT',
#      'tool_name': 'talk_to_user',
#      'tool_result': 'I need to go to Orange County. I am in Cupertino.',
#      'tool_status': 'success'},
#     {'tool_args': {'argument_input': {'destination_airport': 'SNA',
#        'source_airport': 'SJC'}},
#      'tool_call_id': 'call_M8lczqCguoV2hz1V8z96d7V1',
#      'tool_name': 'find_direct_routes_between_airports',
#      'tool_result': '[{"airlines":["WN"],"from_airport":"SJC","layovers":[],"to_airport":"SNA"}]',
#      'tool_status': 'success'},
#     {'tool_args': {'argument_input': {'destination_airport': 'SNA',
#        'source_airport': 'SJC'}},
#      'tool_call_id': 'call_M8lczqCguoV2hz1V8z96d7V1',
#      'tool_name': 'find_direct_routes_between_airports',
#      'tool_result': '[{"airlines":["WN"],"from_airport":"SJC","layovers":[],"to_airport":"SNA"}]',
#      'tool_status': 'success'},
#     {'tool_args': {'message': "Do you want to continue? Please respond with 'yes' or 'no'."},
#      'tool_call_id': 'call_M3MJmyGg2lDcYtkwaj3xesTu',
#      'tool_name': 'talk_to_user',
#      'tool_result': 'no',
#      'tool_status': 'success'},
#     {'tool_args': {'message': "Do you want to continue? Please respond with 'yes' or 'no'."},
#      'tool_call_id': 'call_M3MJmyGg2lDcYtkwaj3xesTu',
#      'tool_name': 'talk_to_user',
#      'tool_result': 'no',
#      'tool_status': 'success'}],
#    'vid': {'identifier': '582e23b276386435c59289c13d22df58873631bf',
#     'timestamp': '2024-11-20T18:51:38.490768Z'}}},
#  {'t': {'sid': 'e7378ce5c3e4474ead665a0c066d38ba',
#    'tool_calls': [{'tool_args': {'message': 'Please provide the source airport and the destination airport for your travel. I need the names or locations of both airports to find their IATA codes.'},
#      'tool_call_id': 'call_14TDpsdeOHq73KpGtTJ3TPPl',
#      'tool_name': 'talk_to_user',
#      'tool_result': 'Dest: YNW Source: California',
#      'tool_status': 'success'},
#     {'tool_args': {'message': 'Please provide the source airport and the destination airport for your travel. I need the names or locations of both airports to find their IATA codes.'},
#      'tool_call_id': 'call_14TDpsdeOHq73KpGtTJ3TPPl',
#      'tool_name': 'talk_to_user',
#      'tool_result': 'Dest: YNW Source: California',
#      'tool_status': 'success'},
#     {'tool_args': {'argument_input': {'destination_airport': 'YNW',
#        'source_airport': 'LAX'}},
#      'tool_call_id': 'call_vvBUScBrEVPslDiXLtHhAFgk',
#      'tool_name': 'find_direct_routes_between_airports',
#      'tool_result': '[]',
#      'tool_status': 'success'},
#     {'tool_args': {'argument_input': {'destination_airport': 'YNW',
#        'source_airport': 'LAX'}},
#      'tool_call_id': 'call_vvBUScBrEVPslDiXLtHhAFgk',
#      'tool_name': 'find_direct_routes_between_airports',
#      'tool_result': '[]',
#      'tool_status': 'success'},
#     {'tool_args': {'argument_input': {'destination_airport': 'YNW',
#        'source_airport': 'LAX'}},
#      'tool_call_id': 'call_5T8x9leBwtDUYGZ9L24vnQ0j',
#      'tool_name': 'find_routes_with_one_layover',
#      'tool_result': '[]',
#      'tool_status': 'success'},
#     {'tool_args': {'argument_input': {'destination_airport': 'YNW',
#        'source_airport': 'LAX'}},
#      'tool_call_id': 'call_5T8x9leBwtDUYGZ9L24vnQ0j',
#      'tool_name': 'find_routes_with_one_layover',
#      'tool_result': '[]',
#      'tool_status': 'success'}],
#    'vid': {'identifier': '582e23b276386435c59289c13d22df58873631bf',
#     'timestamp': '2024-11-20T18:51:38.490768Z'}}},
#  {'t': {'sid': '94e814bcc0d24f06ac58352b3709582c',
#    'tool_calls': [{'tool_args': {'message': 'Please provide the source airport and the destination airport. I need the IATA codes for both airports to proceed.'},
#      'tool_call_id': 'call_hGvtFffDEtyhKCb29Q2vJzks',
#      'tool_name': 'talk_to_user',
#      'tool_result': 'I need to go to LAX from YNW',
#      'tool_status': 'success'},
#     {'tool_args': {'message': 'Please provide the source airport and the destination airport. I need the IATA codes for both airports to proceed.'},
#      'tool_call_id': 'call_hGvtFffDEtyhKCb29Q2vJzks',
#      'tool_name': 'talk_to_user',
#      'tool_result': 'I need to go to LAX from YNW',
#      'tool_status': 'success'},
#     {'tool_args': {'argument_input': {'destination_airport': 'LAX',
#        'source_airport': 'YNW'}},
#      'tool_call_id': 'call_Zl8fnDFfnoSmeLdqTQhrJyO3',
#      'tool_name': 'find_direct_routes_between_airports',
#      'tool_result': '[]',
#      'tool_status': 'success'},
#     {'tool_args': {'argument_input': {'destination_airport': 'LAX',
#        'source_airport': 'YNW'}},
#      'tool_call_id': 'call_Zl8fnDFfnoSmeLdqTQhrJyO3',
#      'tool_name': 'find_direct_routes_between_airports',
#      'tool_result': '[]',
#      'tool_status': 'success'},
#     {'tool_args': {'argument_input': {'destination_airport': 'LAX',
#        'source_airport': 'YNW'}},
#      'tool_call_id': 'call_cQMh4C8d5bTpY4HLmrxAV4K2',
#      'tool_name': 'find_routes_with_one_layover',
#      'tool_result': '[]',
#      'tool_status': 'success'},
#     {'tool_args': {'argument_input': {'destination_airport': 'LAX',
#        'source_airport': 'YNW'}},
#      'tool_call_id': 'call_cQMh4C8d5bTpY4HLmrxAV4K2',
#      'tool_name': 'find_routes_with_one_layover',
#      'tool_result': '[]',
#      'tool_status': 'success'},
#     {'tool_args': {'message': "I couldn't find any direct or one-layover routes from YNW to LAX. Could you please provide another source airport that is close to YNW?"},
#      'tool_call_id': 'call_J0FfNq9MOjPFXSRPooUWugFK',
#      'tool_name': 'talk_to_user',
#      'tool_result': 'SFO',
#      'tool_status': 'success'},
#     {'tool_args': {'message': "I couldn't find any direct or one-layover routes from YNW to LAX. Could you please provide another source airport that is close to YNW?"},
#      'tool_call_id': 'call_J0FfNq9MOjPFXSRPooUWugFK',
#      'tool_name': 'talk_to_user',
#      'tool_result': 'SFO',
#      'tool_status': 'success'},
#     {'tool_args': {'argument_input': {'destination_airport': 'LAX',
#        'source_airport': 'SFO'}},
#      'tool_call_id': 'call_vk9eCPS5gYnOmx8aW8I5g6dx',
#      'tool_name': 'find_direct_routes_between_airports',
#      'tool_result': '[{"airlines":["AS"],"from_airport":"SFO","layovers":[],"to_airport":"LAX"},{"airlines":["DL"],"from_airport":"SFO","layovers":[],"to_airport":"LAX"},{"airlines":["UA"],"from_airport":"SFO","layovers":[],"to_airport":"LAX"},{"airlines":["US"],"from_airport":"SFO","layovers":[],"to_airport":"LAX"},{"airlines":["VX"],"from_airport":"SFO","layovers":[],"to_airport":"LAX"},{"airlines":["WN"],"from_airport":"SFO","layovers":[],"to_airport":"LAX"},{"airlines":["AA"],"from_airport":"SFO","layovers":[],"to_airport":"LAX"}]',
#      'tool_status': 'success'},
#     {'tool_args': {'argument_input': {'destination_airport': 'LAX',
#        'source_airport': 'SFO'}},
#      'tool_call_id': 'call_yU0RrBA7It7iDD4IyNrpFWxw',
#      'tool_name': 'find_routes_with_one_layover',
#      'tool_result': '[{"airlines":["AI","CX"],"from_airport":"SFO","layovers":["HKG"],"to_airport":"LAX"},{"airlines":["AI","AA"],"from_airport":"SFO","layovers":["HKG"],"to_airport":"LAX"},{"airlines":["AI","DL"],"from_airport":"SFO","layovers":["ICN"],"to_airport":"LAX"},{"airlines":["AI","KE"],"from_airport":"SFO","layovers":["ICN"],"to_airport":"LAX"},{"airlines":["AI","OZ"],"from_airport":"SFO","layovers":["ICN"],"to_airport":"LAX"},{"airlines":["AI","TG"],"from_airport":"SFO","layovers":["ICN"],"to_airport":"LAX"},{"airlines":["AI","UA"],"from_airport":"SFO","layovers":["ICN"],"to_airport":"LAX"},{"airlines":["AM","AS"],"from_airport":"SFO","layovers":["ATL"],"to_airport":"LAX"},{"airlines":["AM","AZ"],"from_airport":"SFO","layovers":["ATL"],"to_airport":"LAX"},{"airlines":["AM","CI"],"from_airport":"SFO","layovers":["ATL"],"to_airport":"LAX"}]',
#      'tool_status': 'success'},
#     {'tool_args': {'argument_input': {'destination_airport': 'LAX',
#        'source_airport': 'SFO'}},
#      'tool_call_id': 'call_vk9eCPS5gYnOmx8aW8I5g6dx',
#      'tool_name': 'find_direct_routes_between_airports',
#      'tool_result': '[{"airlines":["AS"],"from_airport":"SFO","layovers":[],"to_airport":"LAX"},{"airlines":["DL"],"from_airport":"SFO","layovers":[],"to_airport":"LAX"},{"airlines":["UA"],"from_airport":"SFO","layovers":[],"to_airport":"LAX"},{"airlines":["US"],"from_airport":"SFO","layovers":[],"to_airport":"LAX"},{"airlines":["VX"],"from_airport":"SFO","layovers":[],"to_airport":"LAX"},{"airlines":["WN"],"from_airport":"SFO","layovers":[],"to_airport":"LAX"},{"airlines":["AA"],"from_airport":"SFO","layovers":[],"to_airport":"LAX"}]',
#      'tool_status': 'success'},
#     {'tool_args': {'argument_input': {'destination_airport': 'LAX',
#        'source_airport': 'SFO'}},
#      'tool_call_id': 'call_yU0RrBA7It7iDD4IyNrpFWxw',
#      'tool_name': 'find_routes_with_one_layover',
#      'tool_result': '[{"airlines":["AI","CX"],"from_airport":"SFO","layovers":["HKG"],"to_airport":"LAX"},{"airlines":["AI","AA"],"from_airport":"SFO","layovers":["HKG"],"to_airport":"LAX"},{"airlines":["AI","DL"],"from_airport":"SFO","layovers":["ICN"],"to_airport":"LAX"},{"airlines":["AI","KE"],"from_airport":"SFO","layovers":["ICN"],"to_airport":"LAX"},{"airlines":["AI","OZ"],"from_airport":"SFO","layovers":["ICN"],"to_airport":"LAX"},{"airlines":["AI","TG"],"from_airport":"SFO","layovers":["ICN"],"to_airport":"LAX"},{"airlines":["AI","UA"],"from_airport":"SFO","layovers":["ICN"],"to_airport":"LAX"},{"airlines":["AM","AS"],"from_airport":"SFO","layovers":["ATL"],"to_airport":"LAX"},{"airlines":["AM","AZ"],"from_airport":"SFO","layovers":["ATL"],"to_airport":"LAX"},{"airlines":["AM","CI"],"from_airport":"SFO","layovers":["ATL"],"to_airport":"LAX"}]',
#      'tool_status': 'success'},
#     {'tool_args': {'message': "Do you want to continue? Please respond with 'yes' or 'no'."},
#      'tool_call_id': 'call_u9kH6urFVvgtAA4VigVDlnKJ',
#      'tool_name': 'talk_to_user',
#      'tool_result': 'no',
#      'tool_status': 'success'},
#     {'tool_args': {'message': "Do you want to continue? Please respond with 'yes' or 'no'."},
#      'tool_call_id': 'call_u9kH6urFVvgtAA4VigVDlnKJ',
#      'tool_name': 'talk_to_user',
#      'tool_result': 'no',
#      'tool_status': 'success'}],
#    'vid': {'identifier': '582e23b276386435c59289c13d22df58873631bf',
#     'timestamp': '2024-11-20T18:51:38.490768Z'}}},
#  {'t': {'sid': '4f226e4fdc2e47bebfe378e18bcdc76d',
#    'tool_calls': [{'tool_args': {'message': 'Please provide the names of the source and destination airports, so I can find their IATA codes for you.'},
#      'tool_call_id': 'call_PYswGCWAu3TeY1nlRw0TI3q6',
#      'tool_name': 'talk_to_user',
#      'tool_result': "Let's go to LAX. I'm in SFO.",
#      'tool_status': 'success'},
#     {'tool_args': {'message': 'Please provide the names of the source and destination airports, so I can find their IATA codes for you.'},
#      'tool_call_id': 'call_PYswGCWAu3TeY1nlRw0TI3q6',
#      'tool_name': 'talk_to_user',
#      'tool_result': "Let's go to LAX. I'm in SFO.",
#      'tool_status': 'success'},
#     {'tool_args': {'argument_input': {'destination_airport': 'LAX',
#        'source_airport': 'SFO'}},
#      'tool_call_id': 'call_K6p9RgL4WFzZUK0bJSoRhW1D',
#      'tool_name': 'find_direct_routes_between_airports',
#      'tool_result': '[{"airlines":["AS"],"from_airport":"SFO","layovers":[],"to_airport":"LAX"},{"airlines":["DL"],"from_airport":"SFO","layovers":[],"to_airport":"LAX"},{"airlines":["UA"],"from_airport":"SFO","layovers":[],"to_airport":"LAX"},{"airlines":["US"],"from_airport":"SFO","layovers":[],"to_airport":"LAX"},{"airlines":["VX"],"from_airport":"SFO","layovers":[],"to_airport":"LAX"},{"airlines":["WN"],"from_airport":"SFO","layovers":[],"to_airport":"LAX"},{"airlines":["AA"],"from_airport":"SFO","layovers":[],"to_airport":"LAX"}]',
#      'tool_status': 'success'},
#     {'tool_args': {'argument_input': {'destination_airport': 'LAX',
#        'source_airport': 'SFO'}},
#      'tool_call_id': 'call_K6p9RgL4WFzZUK0bJSoRhW1D',
#      'tool_name': 'find_direct_routes_between_airports',
#      'tool_result': '[{"airlines":["AS"],"from_airport":"SFO","layovers":[],"to_airport":"LAX"},{"airlines":["DL"],"from_airport":"SFO","layovers":[],"to_airport":"LAX"},{"airlines":["UA"],"from_airport":"SFO","layovers":[],"to_airport":"LAX"},{"airlines":["US"],"from_airport":"SFO","layovers":[],"to_airport":"LAX"},{"airlines":["VX"],"from_airport":"SFO","layovers":[],"to_airport":"LAX"},{"airlines":["WN"],"from_airport":"SFO","layovers":[],"to_airport":"LAX"},{"airlines":["AA"],"from_airport":"SFO","layovers":[],"to_airport":"LAX"}]',
#      'tool_status': 'success'},
#     {'tool_args': {'message': "Do you want to continue? Please respond with 'yes' or 'no'."},
#      'tool_call_id': 'call_9BIik2ImaS47SEzllnVn55hY',
#      'tool_name': 'talk_to_user',
#      'tool_result': 'no',
#      'tool_status': 'success'},
#     {'tool_args': {'message': "Do you want to continue? Please respond with 'yes' or 'no'."},
#      'tool_call_id': 'call_9BIik2ImaS47SEzllnVn55hY',
#      'tool_name': 'talk_to_user',
#      'tool_result': 'no',
#      'tool_status': 'success'}],
#    'vid': {'identifier': '582e23b276386435c59289c13d22df58873631bf',
#     'timestamp': '2024-11-20T18:51:38.490768Z'}}},
#  {'t': {'sid': '4431869c6e4541e1a25b1c6f9bec9221',
#    'tool_calls': [{'tool_args': {'message': 'Please provide the source airport and the destination airport for your travel. I will return the IATA codes for both airports.'},
#      'tool_call_id': 'call_Zfgr2OXSLrQR9tvdFijEH2gs',
#      'tool_name': 'talk_to_user',
#      'tool_result': 'Source: LAX, Dest: SFO',
#      'tool_status': 'success'},
#     {'tool_args': {'message': 'Please provide the source airport and the destination airport for your travel. I will return the IATA codes for both airports.'},
#      'tool_call_id': 'call_Zfgr2OXSLrQR9tvdFijEH2gs',
#      'tool_name': 'talk_to_user',
#      'tool_result': 'Source: LAX, Dest: SFO',
#      'tool_status': 'success'},
#     {'tool_args': {'argument_input': {'destination_airport': 'SFO',
#        'source_airport': 'LAX'}},
#      'tool_call_id': 'call_d7Rftm3wQEO9vEgbGDXRXXRt',
#      'tool_name': 'find_direct_routes_between_airports',
#      'tool_result': '[{"airlines":["AS"],"from_airport":"LAX","layovers":[],"to_airport":"SFO"},{"airlines":["DL"],"from_airport":"LAX","layovers":[],"to_airport":"SFO"},{"airlines":["UA"],"from_airport":"LAX","layovers":[],"to_airport":"SFO"},{"airlines":["AA"],"from_airport":"LAX","layovers":[],"to_airport":"SFO"},{"airlines":["US"],"from_airport":"LAX","layovers":[],"to_airport":"SFO"},{"airlines":["VX"],"from_airport":"LAX","layovers":[],"to_airport":"SFO"},{"airlines":["WN"],"from_airport":"LAX","layovers":[],"to_airport":"SFO"}]',
#      'tool_status': 'success'},
#     {'tool_args': {'argument_input': {'destination_airport': 'SFO',
#        'source_airport': 'LAX'}},
#      'tool_call_id': 'call_d7Rftm3wQEO9vEgbGDXRXXRt',
#      'tool_name': 'find_direct_routes_between_airports',
#      'tool_result': '[{"airlines":["AS"],"from_airport":"LAX","layovers":[],"to_airport":"SFO"},{"airlines":["DL"],"from_airport":"LAX","layovers":[],"to_airport":"SFO"},{"airlines":["UA"],"from_airport":"LAX","layovers":[],"to_airport":"SFO"},{"airlines":["AA"],"from_airport":"LAX","layovers":[],"to_airport":"SFO"},{"airlines":["US"],"from_airport":"LAX","layovers":[],"to_airport":"SFO"},{"airlines":["VX"],"from_airport":"LAX","layovers":[],"to_airport":"SFO"},{"airlines":["WN"],"from_airport":"LAX","layovers":[],"to_airport":"SFO"}]',
#      'tool_status': 'success'},
#     {'tool_args': {'message': "Do you want to continue? Please respond with 'yes' or 'no'."},
#      'tool_call_id': 'call_VPM3poCSE3vpYTgwNgOZ6tAr',
#      'tool_name': 'talk_to_user',
#      'tool_result': 'no',
#      'tool_status': 'success'},
#     {'tool_args': {'message': "Do you want to continue? Please respond with 'yes' or 'no'."},
#      'tool_call_id': 'call_VPM3poCSE3vpYTgwNgOZ6tAr',
#      'tool_name': 'talk_to_user',
#      'tool_result': 'no',
#      'tool_status': 'success'}],
#    'vid': {'identifier': '582e23b276386435c59289c13d22df58873631bf',
#     'timestamp': '2024-11-20T18:51:38.490768Z'}}}]
